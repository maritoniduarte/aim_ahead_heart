# %%
import pandas as pd

# %%
mhdata2020 = pd.read_csv('/Users/DELL/Documents/AIM_AHEAD_Data/mhcld-puf-2020-csv.csv')

# %%
mhdata2020_statefip = mhdata2020.set_index("STATEFIP")

# %%
print(mhdata2020_statefip)
# Out:
#           YEAR  AGE  EDUC  ETHNIC  RACE  GENDER  SPHSERVICE  CMPSERVICE  \
# STATEFIP
# 1         2020   14    -9       4     3       1           1           1
# 1         2020    1     2       4     1       1           2           1
# 1         2020    6    -9       4     4       2           2           1
# 1         2020   14    -9       4     3       2           1           1
# 1         2020   13    -9       4     3       2           1           1
# ...        ...  ...   ...     ...   ...     ...         ...         ...
# 72        2020    6     3       3    -9       1           1           2
# 72        2020   12    -9      -9     6       1           2           2
# 72        2020    4    -9       3     1       1           2           1
# 72        2020    7    -9       3     6       1           1           1
# 72        2020   10    -9       3     5       2           2           1
#
#           OPISERVICE  RTCSERVICE  ...  DEPRESSFLG  ODDFLG  PDDFLG  PERSONFLG  \
# ...

# %%
other_mhdata2020 = mhdata2020_statefip.loc[99]
puertorico_mhdata2020 = mhdata2020_statefip.loc[72]
hawaii_mhdata2020 = mhdata2020_statefip.loc[15]

# %%
print(other_mhdata2020)
# Out:
#           YEAR  AGE  EDUC  ETHNIC  RACE  GENDER  SPHSERVICE  CMPSERVICE  \
# STATEFIP
# 99        2020    7    -9      -9     6       1           2           1
# 99        2020   11    -9      -9     4       1           2           1
# 99        2020    6    -9      -9     2       2           2           1
# 99        2020   10    -9      -9     4       1           2           1
# 99        2020    8    -9      -9     4       1           2           1
# ...        ...  ...   ...     ...   ...     ...         ...         ...
# 99        2020    8    -9       4     2       1           2           1
# 99        2020    8    -9       4     4       1           2           1
# 99        2020    7     5       4     4       2           2           1
# 99        2020   14     3       4     2       2           2           1
# 99        2020    7    -9       4     4       1           2           1
#
#           OPISERVICE  RTCSERVICE  ...  DEPRESSFLG  ODDFLG  PDDFLG  PERSONFLG  \
# ...

# %%
import pandas as pd
from io import StringIO
from matplotlib import pyplot

# %%
(other_mhdata2020
 .drop(columns=['YEAR', 'AGE', 'EDUC', 'ETHNIC', 'RACE', 'GENDER', 'OPISERVICE', 'RTCSERVICE', 'IJSSERVICE', 'MH2', 'MH3', 'SUB', 'MARSTAT', 'SMISED', 'SAP', 'EMPLOY', 'DETNLF', 'VETERAN', 'LIVARAG', 'NUMMHS', 'TRAUSTREFLG', 'ANXIETYFLG', 'ADHDFLG', 'CONDUCTFLG', 'DELIRDEMFLG', 'BIPOLARFLG', 'DEPRESSFLG', 'ODDFLG', 'PDDFLG', 'PERSONFLG', 'SCHIZOFLG', 'ALCSUBFLG', 'OTHERDISFLG', 'DIVISION', 'REGION', 'CASEID'])
 .groupby('MH1').sum()
 .plot.bar()
)
# Out:
# <AxesSubplot:xlabel='MH1'>

# %%
other_sphservice2020 = other_mhdata2020.groupby('MH1')['SPHSERVICE'].count()
result_other_sphservice2020 = other_mhdata2020.groupby(by=['MH1','SPHSERVICE']).size().reset_index()
result_other_sphservice2020.rename(columns={0:"count"}, inplace=True)

# plot bar graph
result_other_sphservice2020.set_index(["MH1","SPHSERVICE"])['count'].unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='MH1'>

# %%
other_cmpservice2020 = other_mhdata2020.groupby('MH1')['CMPSERVICE'].count()
result_other_cmpservice2020 = other_mhdata2020.groupby(by=['MH1','CMPSERVICE']).size().reset_index()
result_other_cmpservice2020.rename(columns={0:"count"}, inplace=True)

# plot bar graph
result_other_cmpservice2020.set_index(["MH1","CMPSERVICE"])['count'].unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='MH1'>

# %%
print(puertorico_mhdata2020)
# Out:
#           YEAR  AGE  EDUC  ETHNIC  RACE  GENDER  SPHSERVICE  CMPSERVICE  \
# STATEFIP
# 72        2020    5     4       2     5       1           2           2
# 72        2020   12     4       2     6       1           2           1
# 72        2020    4     4       2     6       1           2           1
# 72        2020    7     4       2     6       1           2           1
# 72        2020    4     4       2     6       2           2           1
# ...        ...  ...   ...     ...   ...     ...         ...         ...
# 72        2020    6     3       3    -9       1           1           2
# 72        2020   12    -9      -9     6       1           2           2
# 72        2020    4    -9       3     1       1           2           1
# 72        2020    7    -9       3     6       1           1           1
# 72        2020   10    -9       3     5       2           2           1
#
#           OPISERVICE  RTCSERVICE  ...  DEPRESSFLG  ODDFLG  PDDFLG  PERSONFLG  \
# ...

# %%
puertorico_sphservice2020 = puertorico_mhdata2020.groupby('MH1')['SPHSERVICE'].count()
result_puertorico_sphservice2020 = puertorico_mhdata2020.groupby(by=['MH1','SPHSERVICE']).size().reset_index()
result_puertorico_sphservice2020.rename(columns={0:"count"}, inplace=True)

# plot bar graph
result_puertorico_sphservice2020.set_index(["MH1","SPHSERVICE"])['count'].unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='MH1'>

# %%
puertorico_cmpservice2020 = puertorico_mhdata2020.groupby('MH1')['CMPSERVICE'].count()
result_puertorico_cmpservice2020 = puertorico_mhdata2020.groupby(by=['MH1','CMPSERVICE']).size().reset_index()
result_puertorico_cmpservice2020.rename(columns={0:"count"}, inplace=True)

# plot bar graph
result_puertorico_cmpservice2020.set_index(["MH1","CMPSERVICE"])['count'].unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='MH1'>

# %%
print(hawaii_mhdata2020)
# Out:
#           YEAR  AGE  EDUC  ETHNIC  RACE  GENDER  SPHSERVICE  CMPSERVICE  \
# STATEFIP
# 15        2020   13     4       4     4       1           2           1
# 15        2020    8     4       4     6       1           1           1
# 15        2020   13    -9       4     2       1           1           1
# 15        2020    6    -9       4     2       1           1           1
# 15        2020    9    -9       4     2       1           1           1
# ...        ...  ...   ...     ...   ...     ...         ...         ...
# 15        2020    6    -9      -9     3       1           2           1
# 15        2020   13    -9      -9    -9       2           2           1
# 15        2020   14    -9      -9    -9       1           2           1
# 15        2020   14    -9       4     3       1           2           1
# 15        2020   11     4       4     5       1           2           1
#
#           OPISERVICE  RTCSERVICE  ...  DEPRESSFLG  ODDFLG  PDDFLG  PERSONFLG  \
# ...

# %%
hawaii_sphservice2020 = hawaii_mhdata2020.groupby('MH1')['SPHSERVICE'].count()
result_hawaii_sphservice2020 = hawaii_mhdata2020.groupby(by=['MH1','SPHSERVICE']).size().reset_index()
result_hawaii_sphservice2020.rename(columns={0:"count"}, inplace=True)

# plot bar graph
result_hawaii_sphservice2020.set_index(["MH1","SPHSERVICE"])['count'].unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='MH1'>

# %%
hawaii_cmpservice2020 = hawaii_mhdata2020.groupby('MH1')['CMPSERVICE'].count()
result_hawaii_cmpservice2020 = hawaii_mhdata2020.groupby(by=['MH1','CMPSERVICE']).size().reset_index()
result_hawaii_cmpservice2020.rename(columns={0:"count"}, inplace=True)

# plot bar graph
result_hawaii_cmpservice2020.set_index(["MH1","CMPSERVICE"])['count'].unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='MH1'>
